# %% [markdown]
# # Table of Contents
# 1. Introduction [purpose, agenda, alignment]
#     - What do you know about Transformers
#     - What exactly is Transformers
#     - Why we should care about it
# 2. Fundamental Concept [key definitions, concepts]
#     - Attention
#     - Self-Attention
# 3. Deep Dive [architecture and workflow, step on how it works]
#     - architecture
#     - how it works
# 4. Real-world applications [use cases, how they impact your business/product]
# 5. Interactions [Questions&Answers, polls, scenario discussion]
# 6. Hands-On [case study, practical implementation]
# 7. Conclusion [summary, resources, what to do next]

# %% [markdown]
# # 1. Introduction [purpose, agenda, alignment]
#     - What do you know about Transformers
#     - What exactly is Transformers
#     - Why we should care about it

# %%
big computer that reduces the gap between a human and a machine

# %%
transformer is a neural network architecture

it is updated version of RNN and LSTM

it overcome problems in RNN and LSTM

# %% [markdown]
# # 2. Fundamental Concept [key definitions, concepts]
#     - Attention
#     - Self-Attention

# %%
context

"your t-shirt is killer"
  1     2     3    4

# %%
intent

"my mom gave me money to buy tomatos and she will be angry if i dont bring them home"

# %%
- transformers process the input all at once
- they need positional encoding to know the order
- it can capture long range dependencies

# %%
To capture long term dependencies we have 

attention mechanism

- the model will focus on the most relevant parts of the input

# %%
self-attention

- the model does not just focus on 1 word as a time
- it is going to focus on every word in the input and figure out how they are related to each other

# %% [markdown]
# # 3. Deep Dive [architecture and workflow, step on how it works]
#     - architecture
#     - how it works

# %% [markdown]
# # Sequence Transduction
#
# <img src='t1.gif' />

# %%
- machine translation

# %% [markdown]
# # Recurrent Neural Network
#
# <img src='t2.gif' />

# %%
- long term dependencies

# %% [markdown]
# # Long Short Term Memory (LSTM)
#
# <img src='t3.png' />

# %%
3 problems of LSTM and RNN

- sequential computation parallelization - it cannot process all the words together
- long and short range dependencies
- distance is linear

# %%
RNN architectures

- bidirectional RNN
- Gated Recurrent Unit (GRU)
- Long Short Term Memory (LSTM)

# %% [markdown]
# # Attention
#
#
# <img src='t4.gif' />

# %%
paying attention to specific words

"Inverters is a great band. They play very well."

"Himanshu is taking session. He will help you solve the problem"

# %% [markdown]
# <img src='t5.gif' />

# %% [markdown]
# <img src='t6.gif' />

# %%
prallel computation is not solved here

even if you are using the concept of attention with RNN

# %% [markdown]
# # Convolutional Neural Network
#
# <img src='t7.gif' />

# %%
lets use = CNN + Attention 

CNNs with attention

# %% [markdown]
# # Transformer
#
# ![image.png](attachment:image.png)
#
# <img src='t8.png' />

# %%
transformer use attention to boost the speed, more specifically self-attention

attention -> assign different weights to the input sequence, based on relevant parts

self-attention -> intra-attention/inner attention
                it will assign weigths based on the importance of each element 
                in relation to other within the same sequence.

# %% [markdown]
# <img src='t9.png' />

# %%
encoder
- self-attention
- feed forward neural network

# %% [markdown]
# <img src='t10.png' />

# %%
decoder
- self-attention
- encoder-decoder attention
- feed forward neural network

# %% [markdown]
# # Self-Attention
#
# <img src='t11.png' />

# %%
each input of the self attention is split into 3 transformations

- query
- key
- value


using these values you can generate attention score

# %% [markdown]
# <img src='t12.png' />

# %%
steps

1 - calculating the self-attention

for each word

- query vectors 
- key vectors
- value vector

# %% [markdown]
# <img src='t13.png' />

# %%
2 - calulating a score

the score determines how much focus to palce on other parts of the input sentence

# %% [markdown]
# <img src='t14.png' />

# %%
3 and 4th step

- divide this score by 8 (sq root 64 - dimension of the key vector)

- pass that through softmax

# %% [markdown]
# <img src='t15.png' />

# %%
5 - multiplication of each vector


focus on keeping the value of words

# %% [markdown]
# <img src='t16.png' />

# %%
6 - step

sum up the weighted value vectors

# %% [markdown]
# # Multi-thread Attention
#
# <img src='t17.png' />

# %% [markdown]
# # 4. Real-world applications [use cases, how they impact your business/product]

# %%
- NLP
    - Chatbots and conversational agents
        - ChatGPT
        - Google Assistant
        - Microsoft Cortana
    - Language translation
        - google translate
        - deepL
        - microsoft translator
    - text summarization
        - salesforce, huggingface
        - T5, BART
    - Sentiment analysis
        - FB, twitter, IBM watson
    - search engines
        - RankBrain
        - bert

- generation
    - text generation
        - chatgpt
        - jasper ai
    - code generation
        - github copilot
        - cursor ai
- finance
    - fraud detection
        - JPMorgan
        - mastercard
        - paypal

# %% [markdown]
# AI generated Coke Ad
#
# https://www.facebook.com/watch/?v=1276572062941149

# %% [markdown]
# # 5. Interactions [Questions&Answers, polls, scenario discussion]

# %% [markdown]
# ### customer support automation
#
# An e-commerce company, "ShopEase," experiences high volumes of customer inquiries, especially during peak shopping seasons like Black Friday or holiday sales.
#
# These inquiries range from order tracking, product information, returns, refunds, and personalized product recommendations.
#
# The current support system is overwhelmed by the demand, leading to delays and poor customer satisfaction.

# %%
challenges
- scalability
- response quality
- quick turn around time or efficiency
- personalization

# %%
transformer based chatbot
- GPT-4
- BERT

to automate customer support


key features
- NLU
- contextual responses
- track orders
- personalized recommendations
- 24/7 availability
- multilingual support
- handle complex queries

# %%
Business impact

- customer satisfaction
- cost efficient
- grow revenue
- operational efficiency

# %% [markdown]
# # 6. Hands-On [case study, practical implementation]

# %%
# !pip install transformers
# !pip install tokenizers
# !pip install datasets

# %%
hugging face will give you 2 main libraries

- transformers - text data
- diffusers - image data

# %%
from transformers import pipeline

sentiment_analysis = pipeline(
"sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english")

input_text = [
"It’s a great app, my biggest problem is the card readers regularly do not connect. Which is very poor customer service for us because we have to manually enter our customers debit cards, which takes time. This slows down our efficiency."
]

result = sentiment_analysis(input_text)

print(result)
# Out:
# C:\Users\himan\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# WARNING:tensorflow:From C:\Users\himan\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# ...

# %% [markdown]
# ## Microsoft DialoGPT-medium

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
hf_model = "microsoft/DialoGPT-medium"
max_length = 1000

tokenizer = AutoTokenizer.from_pretrained(hf_model)
model = AutoModelForCausalLM.from_pretrained(hf_model)
# Out:
# tokenizer_config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# C:\Users\himan\anaconda3\lib\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\himan\.cache\huggingface\hub\models--microsoft--DialoGPT-medium. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
user_prompt_hf = "If dinosaurs were alive today, would they possess a threat to people?"

# %%
user_input_ids = tokenizer.encode(user_prompt_hf + tokenizer.eos_token, return_tensors='pt')
response_hf_encoded = model.generate(user_input_ids,
                             max_length=max_length,
                             pad_token_id=tokenizer.eos_token_id)

response_hf = tokenizer.decode(response_hf_encoded[:, user_input_ids.shape[-1]:][0], skip_special_tokens=True)

print(f"\n\nPrompt: {user_prompt_hf}\n\n{hf_model}'s Response: \n{response_hf}")
# Out:
# Prompt: If dinosaurs were alive today, would they possess a threat to people?
#
# microsoft/DialoGPT-medium's Response:
# I think they would be more afraid of the humans.

# %% [markdown]
# ### Questions answering web application with flask
#
# https://medium.com/@anoopjohny2000/building-a-question-answering-web-application-with-flask-and-transformers-9af2f69ef33d

# %%
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import Trainer, TrainingArguments
from datasets import load_dataset

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)

dataset = load_dataset('yelp_review_full')
def tokenize_function(examples):
    return tokenizer(examples['text'], padding="max_length", truncation=True)

tokenized_dataset = dataset.map(tokenize_function, batched=True)
small_train_dataset = tokenized_dataset["train"].shuffle(seed=42).select([i for i in range(1000)])
small_test_dataset = tokenized_dataset["test"].shuffle(seed=42).select([i for i in range(1000)])

training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=small_train_dataset,
    eval_dataset=small_test_dataset,
)

trainer.train()
# Out:
# C:\Users\himan\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# WARNING:tensorflow:From C:\Users\himan\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# ...

# %%
import torch

def predict_sentiment(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    logits = outputs.logits
    predicted_class = torch.argmax(logits, dim=1).item()
    return "Positive" if predicted_class == 1 else "Negative"

text = "The product is amazing and I love it!"
print(predict_sentiment(text))

text = "The service was terrible, never coming back!"
print(predict_sentiment(text))
# Out:
# Negative
# Negative

# %% [markdown]
# # 7. Conclusion [summary, resources, what to do next]

# %% [markdown]
# https://www.datacamp.com/tutorial/how-transformers-work

# %%
- transformers are good with text data
- all use cases and nlp tasks can be solved by transformers
